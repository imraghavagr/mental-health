# %%
import os
import sys
from importlib import reload
import requests
import click
import hydra

BASE_DIR = os.path.abspath("../")
if BASE_DIR not in sys.path:
    sys.path = [BASE_DIR] + sys.path

from scripts.data import download
reload(download)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /mnt/569013e9-d6c9-40ca-b4a9-2355022e7589/Projects/mental-health/notebooks/01-ip-data.ipynb Cell 1' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/mnt/569013e9-d6c9-40ca-b4a9-2355022e7589/Projects/mental-health/notebooks/01-ip-data.ipynb#ch0000000?line=3'>4</a> import requests
#       <a href='vscode-notebook-cell:/mnt/569013e9-d6c9-40ca-b4a9-2355022e7589/Projects/mental-health/notebooks/01-ip-data.ipynb#ch0000000?line=4'>5</a> import click
# ----> <a href='vscode-notebook-cell:/mnt/569013e9-d6c9-40ca-b4a9-2355022e7589/Projects/mental-health/notebooks/01-ip-data.ipynb#ch0000000?line=5'>6</a> import hydra
#       <a href='vscode-notebook-cell:/mnt/569013e9-d6c9-40ca-b4a9-2355022e7589/Projects/mental-health/notebooks/01-ip-data.ipynb#ch0000000?line=7'>8</a> BASE_DIR = os.path.abspath("../")
# ...

# %%
download.download_file("url", "name")
# Out:
# Usage: name [OPTIONS] URL FILENAME
# Try 'name --help' for help.
#
# Error: Got unexpected extra argument (l)
# ---------------------------------------------------------------------------
# UsageError                                Traceback (most recent call last)
# File ~/anaconda3/envs/mentalHealth/lib/python3.9/site-packages/click/core.py:1054, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    <a href='file:///home/indrap24/anaconda3/envs/mentalHealth/lib/python3.9/site-packages/click/core.py?line=1052'>1053</a> try:
# -> <a href='file:///home/indrap24/anaconda3/envs/mentalHealth/lib/python3.9/site-packages/click/core.py?line=1053'>1054</a>     with self.make_context(prog_name, args, **extra) as ctx:
#    <a href='file:///home/indrap24/anaconda3/envs/mentalHealth/lib/python3.9/site-packages/click/core.py?line=1054'>1055</a>         rv = self.invoke(ctx)
#
# ...
