# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/Mental Health Checker.csv')
label = pd.read_csv('../data/raw/Label_info.csv')

# %%
df.head()
# Out:
#                       Timestamp  gender    age   education  marital income  \
# 0   2021/05/05 3:59:05 PM GMT+6  Female  20-26  University   single    <10
# 1   2021/05/17 2:07:23 PM GMT+6    Male  20-26  University  married    <10
# 2   2021/05/17 2:09:05 PM GMT+6  Female  13-19     College   single    <10
# 3  2021/05/17 10:08:23 PM GMT+6  Female  13-19     College   single    <10
# 4  2021/05/17 10:35:16 PM GMT+6  Female  20-26  University   single    <10
#
#   loan friend_no friend_help friend_interact  ... thoughts_command self_harm  \
# 0   no      none       maybe            none  ...            maybe       yes
# 1   no        3+         yes               1  ...              yes        no
# 2   no         1         yes               1  ...              yes        no
# 3   no         1          no            none  ...            maybe       yes
# 4   no        3+         yes               3  ...              yes       yes
#
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'gender', 'age', 'education', 'marital', 'income', 'loan',
#        'friend_no', 'friend_help', 'friend_interact', 'share_feel',
#        'have_someone', 'lonely', 'bullied', 'family_support', 'compare_life',
#        'social_media', 'hangout', 'home_time', 'religious', 'goal', 'suicidal',
#        'sleep_disorder', 'mental_disorder', 'love_someone', 'die_someone',
#        'thoughts_command', 'self_harm', 'thoughts_acted', 'thoughts_acted2',
#        'thoughts_time', 'voices', 'harming_others', 'suicide',
#        'suicidal_thoughts', 'therapy'],
#       dtype='object')

# %%
label['Question'][label['Label'] == 'gender'].values[0]
# Out:
# 'Select your gender'

# %%
for x in df.iloc[:, 1:].columns:
    print("Label: ", x)
    print("Question: ", label['Question'][label['Label'] == x].values[0])
    x = df[x].unique()
    for y in x:
        print(y, end='\n')
    print("*"*40)
# Out:
# Label:  gender
# Question:  Select your gender
# Female
# Male
# ****************************************
# Label:  age
# Question:  How old are you?
# 20-26
# 13-19
# 34-44
# 27-33
# 45 or more
# ****************************************
# Label:  education
# Question:  Education
# University
# College
# nan
# School
# ****************************************
# Label:  marital
# Question:  Marital status
# single
# married
# divorced
# separated
# ****************************************
# Label:  income
# Question:  Income
# <10
# <20
# 50+
# 30+
# <30
# ****************************************
# Label:  loan
# Question:  Do you have any loan?
# no
# yes
# ****************************************
# Label:  friend_no
# Question:  How many friends do you have?
# none
# 3+
# 1
# 2
# 3
# ****************************************
# Label:  friend_help
# Question:  Do you think your friends are helpful?
# maybe
# yes
# no
# ****************************************
# ...

# %%
df.isna().sum()
# Out:
# Timestamp             0
# gender                0
# age                   0
# education            15
# marital               0
# income                0
# loan                  0
# friend_no             0
# friend_help           0
# friend_interact       0
# share_feel            0
# have_someone          0
# lonely                0
# bullied               0
# family_support        0
# compare_life          0
# social_media          0
# hangout               1
# home_time             0
# religious             0
# goal                  0
# suicidal              0
# sleep_disorder        0
# mental_disorder      18
# love_someone          0
# die_someone           0
# thoughts_command      0
# self_harm             0
# thoughts_acted        0
# thoughts_acted2       0
# thoughts_time        28
# voices                0
# harming_others        0
# suicide               0
# suicidal_thoughts     0
# therapy               0
# dtype: int64

# %%
#df[df['education'].isna() == True]

# %%
df.shape
# Out:
# (207, 36)

# %%
# dropping 'Timestamp' column
df.drop(['Timestamp'],axis = 1,inplace=True)

# %%
df.head()
# Out:
#    gender    age   education  marital income loan friend_no friend_help  \
# 0  Female  20-26  University   single    <10   no      none       maybe
# 1    Male  20-26  University  married    <10   no        3+         yes
# 2  Female  13-19     College   single    <10   no         1         yes
# 3  Female  13-19     College   single    <10   no         1          no
# 4  Female  20-26  University   single    <10   no        3+         yes
#
#   friend_interact share_feel  ... thoughts_command self_harm thoughts_acted  \
# 0            none        idk  ...            maybe       yes            yes
# 1               1        yes  ...              yes        no            yes
# 2               1         no  ...              yes        no            yes
# 3            none      maybe  ...            maybe       yes            yes
# 4               3        yes  ...              yes       yes            yes
#
#   thoughts_acted2 thoughts_time voices harming_others suicide  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             207 non-null    object
#  1   age                207 non-null    object
#  2   education          192 non-null    object
#  3   marital            207 non-null    object
#  4   income             207 non-null    object
#  5   loan               207 non-null    object
#  6   friend_no          207 non-null    object
#  7   friend_help        207 non-null    object
#  8   friend_interact    207 non-null    object
#  9   share_feel         207 non-null    object
#  10  have_someone       207 non-null    object
#  11  lonely             207 non-null    object
#  12  bullied            207 non-null    object
#  13  family_support     207 non-null    object
#  14  compare_life       207 non-null    object
#  15  social_media       207 non-null    object
# ...

# %%
df['education'].mode()[0]
# Out:
# 'University'

# %%
# handling missing values
for x in df.columns:
    if df[x].isnull().sum()>0:
        df[x].fillna(df[x].mode()[0],inplace=True)

# %%
[x for x in df.columns if df[x].isnull().sum()>0]
# Out:
# []

# %%
print(df.shape)
df.head()
# Out:
# (207, 35)
#    gender    age   education  marital income loan friend_no friend_help  \
# 0  Female  20-26  University   single    <10   no      none       maybe
# 1    Male  20-26  University  married    <10   no        3+         yes
# 2  Female  13-19     College   single    <10   no         1         yes
# 3  Female  13-19     College   single    <10   no         1          no
# 4  Female  20-26  University   single    <10   no        3+         yes
#
#   friend_interact share_feel  ... thoughts_command self_harm thoughts_acted  \
# 0            none        idk  ...            maybe       yes            yes
# 1               1        yes  ...              yes        no            yes
# 2               1         no  ...              yes        no            yes
# 3            none      maybe  ...            maybe       yes            yes
# 4               3        yes  ...              yes       yes            yes
#
# ...

# %%
# Label Encoding 
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
for x in df.columns:
    df[x] = le.fit_transform(df[x])
    print(df[x].unique())
    print('*'*20)
# Out:
# [0 1]
# ********************
# [1 0 3 2 4]
# ********************
# [2 0 1]
# ********************
# [3 1 0 2]
# ********************
# [2 3 1 0 4]
# ********************
# [0 1]
# ********************
# [4 3 0 1 2]
# ********************
# [0 2 1]
# ********************
# [4 0 2 3 1]
# ********************
# [0 3 2 1]
# ********************
# [1 2 0]
# ********************
# [3 2 0 4 1]
# ********************
# [1 0]
# ********************
# [1 2 0]
# ********************
# [0 1]
# ********************
# [2 1 0 3]
# ********************
# [4 0 1 3 2]
# ********************
# [0 3 2 4 1]
# ********************
# [0 1]
# ********************
# [0 2 1]
# ********************
# [1 2 0]
# ********************
# [1 0]
# ********************
# [0 2 1 3]
# ********************
# [0 2 1]
# ********************
# [1 0 2]
# ********************
# [0 2 1]
# ********************
# [2 1 0]
# ********************
# [1 0]
# ********************
# [1 0]
# ********************
# [3 0 1 2]
# ...

# %%
df.head()
# Out:
#    gender  age  education  marital  income  loan  friend_no  friend_help  \
# 0       0    1          2        3       2     0          4            0
# 1       1    1          2        1       2     0          3            2
# 2       0    0          0        3       2     0          0            2
# 3       0    0          0        3       2     0          0            1
# 4       0    1          2        3       2     0          3            2
#
#    friend_interact  share_feel  ...  thoughts_command  self_harm  \
# 0                4           0  ...                 0          2
# 1                0           3  ...                 2          1
# 2                0           2  ...                 2          1
# 3                4           1  ...                 0          2
# 4                2           3  ...                 2          2
#
#    thoughts_acted  thoughts_acted2  thoughts_time  voices  harming_others  \
# ...
